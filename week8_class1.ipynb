# %%
# take user input and make 4 function
def addition(num1,num2):
  return num1 + num2;

def subtraction(num1,num2):
  return num1 - num2;

def multiplication(num1,num2):
  return num1 * num2;

def division(num1,num2):
  return round(num1/num2,2);

num1  = int(input("Enter number 1 "))
num2 = int(input("Enter number 2 "))
print("addition result ",addition(num1,num2))
print("subtraction result ",subtraction(num1,num2))
print("multiplication result",multiplication(num1,num2))
print("division result",division(num1,num2))
# Out:
# Enter number 1 56
# Enter number 2 34
# addition result  90
# subtraction result  22
# multiplication result 1904
# division result 1.65

# %%
# scopping
def g(y):
  y = 1
  y +=1
  print(y)


x=5
g(x)
print(x)
# Out:
# 2
# 5

# %%
# nested functions
def f():
  def g():
    print("Enter g")

  g()
  print("Enter F")

f()
# Out:
# Enter g
# Enter F

# %%
def name1(x):
  def name2(y):
    def name3(z):
      return x+y+z;
    return name3;
  return name2;

res = name1('M')
print(res)
res1 = res('Nihal')
print(res1("Iqbal"))
# Out:
# <function num1.<locals>.num2 at 0x7ed828ad48b0>
# MNihalIqbal
