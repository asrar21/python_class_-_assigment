# %%
#Static and Dynamic Programming

# %%
mass = float(input("Enter your Mass:"))
acc = float(input("Enter your Acceleration:"))
force = mass * acc
print("The product of Mass & Acc is:",force,"N")
# Out:
# Enter your Mass:70
# Enter your Acceleration:5
# The product of Mass & Acc is: 350.0 N

# %%
#sum two number
num1 = float(input("Enter Number 1:"))
num2 = float(input("Enter Number 2:"))
sum = num1 + num2
print("result :", sum)
# Out:
# Enter Number 1:60
# Enter Number 2:200
# result : 260.0

# %%
#diff two number
num1 = float(input("Enter Number 1:"))
num2 = float(input("Enter Number 2:"))
diff = num1 - num2
print("result is :", diff)
# Out:
# Enter Number 1:30
# Enter Number 2:40
# result is : -10.0

# %%
#divide number
num1 = float(input("Enter Number 1:"))
num2 = float(input("Enter Number 2:"))
div = num1 / num2
print("result is :", div)
# Out:
# Enter Number 1:3
# Enter Number 2:4
# result is : 0.75

# %%
2**3 #power
# Out:
# 8

# %%
5//2 # // Floor division operator
# Out:
# 2

# %%
num3 = float(input("take this number:"))
rase_to = float(input("Enter rase number:"))
pow = num3 ** rase_to;
print("your power of number is :",pow)
# Out:
# take this number:2
# Enter rase number:4
# your power of number is : 16.0

# %%
# remainder operator %
4%2
# Out:
# 0

# %%
# type Casting: to change data types of some variables

# %%
name,gender,age,organization,is_job='Asrar Alam','male',25,'AI',True
print(name,gender,age,organization,is_job)
print(type(name),type(gender),type(age),type(organization),type(is_job))
# Out:
# Asrar Alam male 25 AI True
# <class 'str'> <class 'str'> <class 'int'> <class 'str'> <class 'bool'>

# %%
# 5 subjects marks as input ,totla=500, marks_obt,percentage
english = float(input("Enter English marks"))
geography = float(input("Enter Geography marks"))
science = float(input("Enter Science marks"))
history = float(input("Enter history marks"))
psychology = float(input("Enter psychology marks"))
marks_obt = english + geography+science+history+psychology
percentage = (marks_obt/500) * 100
print("your percentage is :",percentage)
# Out:
# Enter English marks60
# Enter Geography marks70
# Enter Science marks80
# Enter history marks85
# Enter psychology marks78
# your percentage is : 74.6
