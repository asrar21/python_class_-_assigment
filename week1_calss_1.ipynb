# %%
#Force , MAss = 4kg , acc = 8m/s2
mass = 4
acc = 8
force = mass * acc
print("The Product of Mass & acceleration is",force)
# Out:
# The Product of Mass & acceleration is 32

# %%
name = 'S.M Asrar Alam'
age = 29
gender ='Male'
designation ='Full stack Developer'
occupation ='Software Engineer'
education = 'Bscs From SSUET'
organization='Simplicore Pak'

print('================================================================')
print('========================Profile=================================')
print("NAME:",name)
print("Age:",age)
print("Gender:",gender)
print("Designation:",designation)
print("Occupation:",occupation)
print("Education:",education)
print("Organization:",organization)
print('================================================================')
# Out:
# ================================================================
# ========================Profile=================================
# NAME: S.M Asrar Alam
# Age: 29
# Gender: Male
# Designation: Full stack Developer
# Occupation: Software Engineer
# Education: Bscs From SSUET
# Organization: Simplicore Pak
# ================================================================
