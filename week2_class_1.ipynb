# %%
#Python Operators
#Relationship operator
print(2>3)
print(4<2)
print(4!=4)
# Out:
# False
# False
# False

# %%
# NOt equal to
# greater than equal to
# less than equal to
# is equal to
#

num_op = float(input("Enter your operator Number is:"))
num_op2 = float(input("Enter your operator Numbers2 is :"))
num_op3 = float(input("Enter your operator Numbers3 is :"))
print("result two Numnber is : ",num_op!=num_op2)
print("result two Numnber is : ",num_op>=num_op2)
print("result two Numnber is : ",num_op<=num_op2)
print("result two Numnber is : ",num_op<num_op2)
print("result two Numnber is : ",num_op==num_op2)

print("result Three Numnber is : ",num_op!=num_op2!=num_op3)
print("result Three Numnber is : ",num_op>=num_op2>=num_op3)
print("result Three Numnber is : ",num_op<=num_op2<=num_op3)
print("result Three Numnber is : ",num_op<num_op2<num_op3)
print("result Three Numnber is : ",num_op==num_op2==num_op3)
# Out:
# Enter your operator Number is:40
# Enter your operator Numbers2 is :50
# Enter your operator Numbers3 is :60
# result two Numnber is :  True
# result two Numnber is :  False
# result two Numnber is :  True
# result two Numnber is :  True
# result two Numnber is :  False
# result Three Numnber is :  True
# result Three Numnber is :  False
# result Three Numnber is :  True
# result Three Numnber is :  True
# result Three Numnber is :  False

# %%
#Logical Operators
# And Operator
matter_num1 = bool(input("Enter matter num1"))
matter_num2 = bool(input("Enter matter num2"))
print("result is :",matter_num1 and matter_num2)
# Out:
# Enter matter num150
# Enter matter num290
# result is : True

# %%
# OR Operator
number1 = bool(input("Enter matter num1"))
number2 =  bool(input("Enter matter num2"))
number1 or number2
print("result is : ",number1 or number2)
# Out:
# Enter matter num180
# Enter matter num2200
# result is :  True

# %%
# Not Operator
number3 =  bool(input("Enter matter num3"))
not number3
print("Enter ",not number3)
# Out:
# Enter matter num3400
# Enter  False

# %%
a = 'Python'
b = 'abc'
a and b
# Out:
# 'abc'

# %%
a = ''
b = 'abc'
a and b
# Out:
# ''

# %% [markdown]
# ##Assignment Operator

# %%
number = 10
number+= 5
print(number)
# Out:
# 15

# %%
number_rev = float(input("Enter reverse number"))
number_rev2 = number_rev + 5
print("result is: ",number_rev2)
# Out:
# Enter reverse number10
# result is:  15.0

# %% [markdown]
# ##Identity Operator

# %%
# is opertor
a=5
b=4
a is b
# Out:
# False

# %%
# is not  opertor
a = 5
b = 4
a is not b
# Out:
# True

# %%
para_1 = 'is a song by American singer Lady Gaga (pictured) from her third extended play, The Fame Monster (2009). Gaga wrote and produced the song with RedOne. It is an electropop and dance-pop song with a spoken bridge. The lyrics, which describe Gagas attraction to unhealthy romantic relationships, were drawn from the paranoia she experienced while on tour. "Bad Romance" topped charts in more than 20 countries and sold 12 million copies worldwide, becoming one of the best-selling singles of all time. It won two Grammy Awards and was named one of Rolling Stones 500 Greatest Songs of All Time.'
para_1 = 'is a song by American singer Lady Gaga (pictured) from her third extended play, The Fame Monster (2009). Gaga wrote and produced the song with RedOne. It is an electropop and dance-pop song with a spoken bridge. The lyrics, which describe Gagas attraction to unhealthy romantic relationships, were drawn from the paranoia she experienced while on tour. "Bad Romance" topped charts in more than 20 countries and sold 12 million copies worldwide, becoming one of the best-selling singles of all time. It won two Grammy Awards and was named one of Rolling Stones 500 Greatest Songs of All Time.'
para_1 is  para_1
print(para_1 is  para_1)
print(id(para_1))
print(id(para_1))
# Out:
# True
# 101208021228784
# 101208021228784

# %%
# in membership Operator
fruits = 'apple'
'a' in fruits
# Out:
# True

# %%
# not in membership operator
fruits = 'apple'
'a' not in fruits
# Out:
# False
