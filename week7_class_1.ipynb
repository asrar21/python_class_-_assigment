# %%
init_temp = ["Apple","Cat",["Banana","Caterpillar"]]
print(type(init_temp))
for item in init_temp:
  print(item)
  i=0
  while type(item) == 'list':
    print(item[i])
    i +=1
# Out:
# <class 'list'>
# Apple
# Cat
# ['Banana', 'Caterpillar']

# %%
# pattern 2
rows = int(input("Enter Number of Rows :"))
for i in range(1,rows+1):
  for j in range(1,i+1):
    print(j,end='')

  print()
# Out:
# Enter Number of Rows :5
# 1
# 12
# 123
# 1234
# 12345

# %%
# pattern 3
row_number = int(input("Enter Rows of number "))
# for i in range(1,row_number+1):
#   for j in range(1,i+1):
#     print(j,end='')
#     for k in range(i-1,0,-1):
#       print(k,end='')

#   print()
for i in range(1,row_number+1):
  for j in range(1,i+1):
    print(j,end='')
    for k in range(i-1,0,-1):
      print(k,end='')

  print()
# Out:
# Enter Rows of number 6
# 1
# 1121
# 121221321
# 1321232133214321
# 1432124321343214432154321
# 154321254321354321454321554321654321

# %%
# functions in python
def welcome(name):
  print("Good Morning " ,name," Have anice day")

def add(num1,num2):
  return num1 + num2;
def isEven(num):
  if num%2==0:
    print("Number is even")
  else:
    print("Number is odd")
def calculateAreaAndCircumFerence(radius):
  pi = 3.4
  print("circumfernece434 of a circle is ",2 *(pi)* radius)
  print("area of a circle is ",pi* (radius ** 2))

radius = float(input("Enter radius "))
calculateAreaAndCircumFerence(radius)
name = input("Enter Your Name ")
welcome(name)



num1 = float(input("Enter Num 1 "))
num2 = float(input("Enter Num 2 "))

result = add(num1,num2)
print(result)




num = int(input("Enter Any number to check even a or odd ?? "))

isEven(num)
# Out:
# Enter radius 34
# circumfernece434 of a circle is  231.2
# area of a circle is  3930.4
# Enter Your Name asrar
# Good Morning  asrar  Have anice day
# Enter Num 1 34
# Enter Num 2 434
# 468.0
# Enter Any number to check even a or odd ?? 45
# Number is odd
