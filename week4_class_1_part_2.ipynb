# %%
# Conditional statements
# if, else
age=float(input("Enter Your Age : "))
if age>=18:
  print("You can cast  a vote your age is :",age)
elif age == 18:
  print("your age is {age}")
else:
     print("You cannot cast  a vote")

print("I am outside Block")
# Out:
# Enter Your Age : 20
# You can cast  a vote your age is : 20.0
# I am outside Block
